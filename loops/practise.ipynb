# %%
i=1
while i <= 5:
    print("hello")
    i = i+1
# Out:
# hello
# hello
# hello
# hello
# hello

# %%
for i in range(5,11):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9
# 10

# %%
num = 50
while num>=35:
    print(num)
    num = num- 1

# %%
yr = 1800

while yr <= 2026:
    print(yr)
    yr+=1

# %%
n=75
while  n<=100:
    if n%2 ==0:
        print(n)
        n+=1

# %%
num = int(input ("enter the number whose factorial is to be found: "))
factorial = 1
for i in range(1,5):
    factorial=factorial*i  #1,1*2,2*3,6*4

print(factorial)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 num = int(input ("enter the number whose factorial is to be found: "))
#       2 factorial = 1
#       3 for i in range(1,5):
#
# ValueError: invalid literal for int() with base 10: ''
